# %%
# %python
df.printSchema()
# Out:
# root
#  |-- Month: string (nullable = true)
#  |--  "1958": double (nullable = true)
#  |--  "1959": double (nullable = true)
#  |--  "1960": double (nullable = true)

# %%
# %python
df_clean = df.dropna()

df_clean.show()
# Out:
# +-----+-------+-------+-------+
# |Month| "1958"| "1959"| "1960"|
# +-----+-------+-------+-------+
# |  JAN|  340.0|  360.0|  417.0|
# |  FEB|  318.0|  342.0|  391.0|
# |  MAR|  362.0|  406.0|  419.0|
# |  APR|  348.0|  396.0|  461.0|
# |  MAY|  363.0|  420.0|  472.0|
# |  JUN|  435.0|  472.0|  535.0|
# |  JUL|  491.0|  548.0|  622.0|
# |  AUG|  505.0|  559.0|  606.0|
# |  SEP|  404.0|  463.0|  508.0|
# |  OCT|  359.0|  407.0|  461.0|
# |  NOV|  310.0|  362.0|  390.0|
# |  DEC|  337.0|  405.0|  432.0|
# +-----+-------+-------+-------+

# %%
# %python
df = spark.read.csv("/Volumes/workspace/default/project_data/airtravel (1).csv", header=True, inferSchema=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %python
df.write.mode("overwrite").parquet("/Volumes/workspace/default/project_data/airtravel_parquet")

# %%
# %python
parquet_df = spark.read.parquet("/Volumes/workspace/default/project_data/airtravel_parquet")

parquet_df.show()
# Out:
# +-----+-------+-------+-------+
# |Month| "1958"| "1959"| "1960"|
# +-----+-------+-------+-------+
# |  JAN|  340.0|  360.0|  417.0|
# |  FEB|  318.0|  342.0|  391.0|
# |  MAR|  362.0|  406.0|  419.0|
# |  APR|  348.0|  396.0|  461.0|
# |  MAY|  363.0|  420.0|  472.0|
# |  JUN|  435.0|  472.0|  535.0|
# |  JUL|  491.0|  548.0|  622.0|
# |  AUG|  505.0|  559.0|  606.0|
# |  SEP|  404.0|  463.0|  508.0|
# |  OCT|  359.0|  407.0|  461.0|
# |  NOV|  310.0|  362.0|  390.0|
# |  DEC|  337.0|  405.0|  432.0|
# +-----+-------+-------+-------+

# %%
# %python
parquet_df.createOrReplaceTempView("airtravel")

# %%
# %sql
SELECT * FROM airtravel;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6429526893961151>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT * FROM airtravel;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:192, in SqlMagic.sql(self, line, cell)
#     186 except BaseException as e:
# ...

# %%
spark.sql("SELECT * FROM airtravel").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6429526893961152>, line 1
# ----> 1 spark.sql("SELECT * FROM airtravel").show()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/session.py:879, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#     876         _views.append(SubqueryAlias(df._plan, name))
#     878 cmd = SQL(sqlQuery, _args, _named_args, _views)
# --> 879 data, properties, ei = self.client.execute_command(cmd.command(self._client))
# ...

# %%
parquet_df.createOrReplaceTempView("airtravel")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-6429526893961153>, line 1
# ----> 1 parquet_df.createOrReplaceTempView("airtravel")
#
# NameError: name 'parquet_df' is not defined

# %%
parquet_df = spark.read.parquet("/Volumes/workspace/default/project_data/airtravel_parquet")

parquet_df.show()
# Out:
# +-----+-------+-------+-------+
# |Month| "1958"| "1959"| "1960"|
# +-----+-------+-------+-------+
# |  JAN|  340.0|  360.0|  417.0|
# |  FEB|  318.0|  342.0|  391.0|
# |  MAR|  362.0|  406.0|  419.0|
# |  APR|  348.0|  396.0|  461.0|
# |  MAY|  363.0|  420.0|  472.0|
# |  JUN|  435.0|  472.0|  535.0|
# |  JUL|  491.0|  548.0|  622.0|
# |  AUG|  505.0|  559.0|  606.0|
# |  SEP|  404.0|  463.0|  508.0|
# |  OCT|  359.0|  407.0|  461.0|
# |  NOV|  310.0|  362.0|  390.0|
# |  DEC|  337.0|  405.0|  432.0|
# +-----+-------+-------+-------+

# %%
parquet_df.createOrReplaceTempView("airtravel")

# %%
# %sql
SELECT * FROM airtravel;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT Month, 1960
FROM airtravel
ORDER BY 1960 DESC;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7233712159231142>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT Month, 1960\nFROM airtravel\nORDER BY 1960 DESC;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:192, in SqlMagic.sql(self, line, cell)
# ...

# %%
parquet_df = spark.read.parquet("/Volumes/workspace/default/project_data/airtravel_parquet")

parquet_df.createOrReplaceTempView("airtravel")

# %%
# %sql
SELECT Month, `1958`, `1959`, `1960`
FROM airtravel;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7233712159231144>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT Month, `1958`, `1959`, `1960`\nFROM airtravel;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:192, in SqlMagic.sql(self, line, cell)
# ...

# %%
parquet_df = spark.read.parquet("/Volumes/workspace/default/project_data/airtravel_parquet")

parquet_df.createOrReplaceTempView("airtravel")

parquet_df.show()
# Out:
# +-----+-------+-------+-------+
# |Month| "1958"| "1959"| "1960"|
# +-----+-------+-------+-------+
# |  JAN|  340.0|  360.0|  417.0|
# |  FEB|  318.0|  342.0|  391.0|
# |  MAR|  362.0|  406.0|  419.0|
# |  APR|  348.0|  396.0|  461.0|
# |  MAY|  363.0|  420.0|  472.0|
# |  JUN|  435.0|  472.0|  535.0|
# |  JUL|  491.0|  548.0|  622.0|
# |  AUG|  505.0|  559.0|  606.0|
# |  SEP|  404.0|  463.0|  508.0|
# |  OCT|  359.0|  407.0|  461.0|
# |  NOV|  310.0|  362.0|  390.0|
# |  DEC|  337.0|  405.0|  432.0|
# +-----+-------+-------+-------+

# %%
# %sql
SELECT * FROM airtravel;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT Month, 1958, 1959, 1960
FROM airtravel;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
parquet_df = spark.read.parquet("/Volumes/workspace/default/project_data/airtravel_parquet")

parquet_df.createOrReplaceTempView("airtravel")

# %%
# %sql

SELECT Month, "1960"
FROM airtravel
ORDER BY "1960" DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Month</th><th>"1960"</th></tr></thead><tbody><tr><td>JAN</td><td>1960</td></tr><tr><td>FEB</td><td>1960</td></tr><tr><td>MAR</td><td>1960</td></tr><tr><td>APR</td><td>1960</td></tr><tr><td>MAY</td><td>1960</td></tr><tr><td>JUN</td><td>1960</td></tr><tr><td>JUL</td><td>1960</td></tr><tr><td>AUG</td><td>1960</td></tr><tr><td>SEP</td><td>1960</td></tr><tr><td>OCT</td><td>1960</td></tr><tr><td>NOV</td><td>1960</td></tr><tr><td>DEC</td><td>1960</td></tr></tbody></table></div>
